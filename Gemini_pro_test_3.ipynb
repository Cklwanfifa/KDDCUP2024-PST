# %%
#!pip install google-generativeai

import google.generativeai as genai
import os 


genai.configure(api_key = "YOUR_API_KEY")
model = genai.GenerativeModel('gemini-1.5-pro-latest')

import pickle

with open('20240528_get_prompt_gpt_detailed_test_V2.pkl', 'rb') as f:
    inspired_data_test_json = pickle.load(f)

gemini_res_test = {}
from tqdm import tqdm
import time

total_key = list(inspired_data_test_json.keys())
print(len(total_key))
# Out:
# 394

# %%
## 分成16组写数据

## 第0组
group_index = 0
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_0 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_0[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_0, f)

## 分成16组写数据

## 第0组
group_index = 1
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_1 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_1[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_1, f)

## 分成16组写数据

## 第0组
group_index = 2
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_2 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_2[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_2, f)

## 分成16组写数据

## 第0组
group_index = 3
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_3 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_3[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_3, f)

## 分成16组写数据

## 第0组
group_index = 4
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_4 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_4[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_4, f)


## 分成16组写数据

## 第0组
group_index = 5
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_5 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_5[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_5, f)

## 分成16组写数据

## 第0组
group_index = 6
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_6 = {}

for ii in tqdm(range(i_start, i_end)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_6[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_6, f)

## 分成16组写数据

## 第0组
group_index = 7
    
i_start = group_index * 50
i_end = (group_index + 1) * 50

gemini_res_test_7 = {}

for ii in tqdm(range(i_start, 394)):
    res = []
    for iii in range(1):
        k = total_key[ii]
        v = inspired_data_test_json[k]
        try:
            response = model.generate_content(v, generation_config=genai.types.GenerationConfig(
        temperature=1.0))
            res.append(response.text)
            time.sleep(30)
        except:
            res.append(-1)
            time.sleep(30)
        
    gemini_res_test_7[k] = res
    #print(f'ii is {ii}, res is {res[-1]}')


with open(f'gemini_res_test_round3_{group_index}.pkl', 'wb') as f:
    pickle.dump(gemini_res_test_7, f)

### 整合所有的结果
## read total valid data
total_test_data = []

for group_index in range(8):
    with open(f'gemini_res_test_round3_{group_index}.pkl', 'rb') as f:
        gemini_res_test = pickle.load(f)
        total_test_data.append(gemini_res_test)

#merge dicts in total_valid_data
my_test_data = {}
for i in range(8):
    my_test_data.update(total_test_data[i])

# 结果补数据
totak_key = list(my_test_data.keys())
for ii in tqdm(range(394)):
    k = totak_key[ii]
    v = my_test_data[k]
    if v == [-1]:
        try:
            res = []
            prompt = inspired_data_test_json[k]
            response = model.generate_content(prompt, generation_config=genai.types.GenerationConfig(
            temperature=1.0))
            res.append(response.text)
            my_test_data[k] = res
            time.sleep(30)
        except:
            print('still error!')
            my_test_data[k] = [-1]

with open(f'gemini_test_result_all_round3.pkl', 'wb') as f:
    pickle.dump(my_test_data, f)
